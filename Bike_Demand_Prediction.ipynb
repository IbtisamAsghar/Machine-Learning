# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load and Inspect the data set

# %%
data = pd.read_csv('/content/bike.csv')

# %%
data
# Out:
#             Date  Rented Bike Count  Hour  Temperature(?C)  Humidity(%)  \
# 0      1/12/2017                254     0             -5.2           37
# 1      1/12/2017                204     1             -5.5           38
# 2      1/12/2017                173     2             -6.0           39
# 3      1/12/2017                107     3             -6.2           40
# 4      1/12/2017                 78     4             -6.0           36
# ...          ...                ...   ...              ...          ...
# 8755  30/11/2018               1003    19              4.2           34
# 8756  30/11/2018                764    20              3.4           37
# 8757  30/11/2018                694    21              2.6           39
# 8758  30/11/2018                712    22              2.1           41
# 8759  30/11/2018                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature  \
# 0                  2.2              2000                  -17.6
# 1                  0.8              2000                  -17.6
# 2                  1.0              2000                  -17.7
# 3                  0.9              2000                  -17.6
# 4                  2.3              2000                  -18.6
# ...                ...               ...                    ...
# 8755               2.6              1894                  -10.3
# 8756               2.3              2000                   -9.9
# 8757               0.3              1968                   -9.9
# 8758               1.0              1859                   -9.8
# 8759               1.3              1909                   -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                         0.0           0.0            0.0  Winter
# 1                         0.0           0.0            0.0  Winter
# 2                         0.0           0.0            0.0  Winter
# 3                         0.0           0.0            0.0  Winter
# 4                         0.0           0.0            0.0  Winter
# ...                       ...           ...            ...     ...
# 8755                      0.0           0.0            0.0  Autumn
# 8756                      0.0           0.0            0.0  Autumn
# 8757                      0.0           0.0            0.0  Autumn
# 8758                      0.0           0.0            0.0  Autumn
# 8759                      0.0           0.0            0.0  Autumn
#
#          Holiday Functioning Day
# 0     No Holiday             Yes
# 1     No Holiday             Yes
# 2     No Holiday             Yes
# 3     No Holiday             Yes
# 4     No Holiday             Yes
# ...          ...             ...
# 8755  No Holiday             Yes
# 8756  No Holiday             Yes
# 8757  No Holiday             Yes
# 8758  No Holiday             Yes
# 8759  No Holiday             Yes
#
# [8760 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     8760 non-null   object
#  1   Rented Bike Count        8760 non-null   int64
#  2   Hour                     8760 non-null   int64
#  3   Temperature(?C)          8760 non-null   float64
#  4   Humidity(%)              8760 non-null   int64
#  5   Wind speed (m/s)         8760 non-null   float64
#  6   Visibility (10m)         8760 non-null   int64
#  7   Dew point temperature    8760 non-null   float64
#  8   Solar Radiation (MJ/m2)  8760 non-null   float64
#  9   Rainfall(mm)             8760 non-null   float64
#  10  Snowfall (cm)            8760 non-null   float64
#  11  Seasons                  8760 non-null   object
#  12  Holiday                  8760 non-null   object
#  13  Functioning Day          8760 non-null   object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 958.2+ KB

# %% [markdown]
# # checking the Null Values

# %%
data.isnull().sum()
# Out:
# Date                       0
# Rented Bike Count          0
# Hour                       0
# Temperature(?C)            0
# Humidity(%)                0
# Wind speed (m/s)           0
# Visibility (10m)           0
# Dew point temperature      0
# Solar Radiation (MJ/m2)    0
# Rainfall(mm)               0
# Snowfall (cm)              0
# Seasons                    0
# Holiday                    0
# Functioning Day            0
# dtype: int64

# %% [markdown]
# # Checking the duplicates

# %%
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Correcting the data types

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')
data['Year'] = data['Date'].dt.year.astype('category')
data['Month'] = data['Date'].dt.month.astype('category')
data['Day'] = data['Date'].dt.day.astype('category')

# %%
data['Seasons'] = data['Seasons'].astype('category')
data['Holiday'] = data['Holiday'].astype('category')
data['Functioning Day'] = data['Functioning Day'].astype('category')

# %%
data.drop('Date',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rented Bike Count        8760 non-null   int64
#  1   Hour                     8760 non-null   int64
#  2   Temperature(?C)          8760 non-null   float64
#  3   Humidity(%)              8760 non-null   int64
#  4   Wind speed (m/s)         8760 non-null   float64
#  5   Visibility (10m)         8760 non-null   int64
#  6   Dew point temperature    8760 non-null   float64
#  7   Solar Radiation (MJ/m2)  8760 non-null   float64
#  8   Rainfall(mm)             8760 non-null   float64
#  9   Snowfall (cm)            8760 non-null   float64
#  10  Seasons                  8760 non-null   category
#  11  Holiday                  8760 non-null   category
#  12  Functioning Day          8760 non-null   category
#  13  Year                     8760 non-null   category
#  14  Month                    8760 non-null   category
#  15  Day                      8760 non-null   category
# dtypes: category(6), float64(6), int64(4)
# memory usage: 737.6 KB

# %%
data.head()
# Out:
#    Rented Bike Count  Hour  Temperature(?C)  Humidity(%)  Wind speed (m/s)  \
# 0                254     0             -5.2           37               2.2
# 1                204     1             -5.5           38               0.8
# 2                173     2             -6.0           39               1.0
# 3                107     3             -6.2           40               0.9
# 4                 78     4             -6.0           36               2.3
#
#    Visibility (10m)  Dew point temperature  Solar Radiation (MJ/m2)  \
# 0              2000                  -17.6                      0.0
# 1              2000                  -17.6                      0.0
# 2              2000                  -17.7                      0.0
# 3              2000                  -17.6                      0.0
# 4              2000                  -18.6                      0.0
#
#    Rainfall(mm)  Snowfall (cm) Seasons     Holiday Functioning Day  Year  \
# 0           0.0            0.0  Winter  No Holiday             Yes  2017
# 1           0.0            0.0  Winter  No Holiday             Yes  2017
# 2           0.0            0.0  Winter  No Holiday             Yes  2017
# 3           0.0            0.0  Winter  No Holiday             Yes  2017
# 4           0.0            0.0  Winter  No Holiday             Yes  2017
#
#   Month Day
# 0    12   1
# 1    12   1
# 2    12   1
# 3    12   1
# 4    12   1

# %% [markdown]
# # Visualization of the data set

# %%
data.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(?C)  Humidity(%)  \
# count        8760.000000  8760.000000      8760.000000  8760.000000
# mean          704.602055    11.500000        12.882922    58.226256
# std           644.997468     6.922582        11.944825    20.362413
# min             0.000000     0.000000       -17.800000     0.000000
# 25%           191.000000     5.750000         3.500000    42.000000
# 50%           504.500000    11.500000        13.700000    57.000000
# 75%          1065.250000    17.250000        22.500000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature  \
# count       8760.000000       8760.000000            8760.000000
# mean           1.724909       1436.825799               4.073813
# std            1.036300        608.298712              13.060369
# min            0.000000         27.000000             -30.600000
# 25%            0.900000        940.000000              -4.700000
# 50%            1.500000       1698.000000               5.100000
# 75%            2.300000       2000.000000              14.800000
# max            7.400000       2000.000000              27.200000
#
#        Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)
# count              8760.000000   8760.000000    8760.000000
# mean                  0.569111      0.148687       0.075068
# std                   0.868746      1.128193       0.436746
# min                   0.000000      0.000000       0.000000
# 25%                   0.000000      0.000000       0.000000
# 50%                   0.010000      0.000000       0.000000
# 75%                   0.930000      0.000000       0.000000
# max                   3.520000     35.000000       8.800000

# %%
plt.figure(figsize=(25,20))
for i,col in enumerate(data.select_dtypes(include ='category').columns):
  plt.subplot(3,3,i+1)
  sns.barplot(x=col,y='Rented Bike Count',data=data,palette="pastel")
  plt.xlabel(col)
  plt.ylabel('count')
  plt.title(f'Barplot for Bike REntal Distribution with {col}')

# %% [markdown]
# # count of observations in each category.

# %%
plt.figure(figsize=(25,20))
for i,col in enumerate(data.select_dtypes(include ='category').columns):
  plt.subplot(3,3,i+1)
  sns.countplot(x=col,data=data,palette="deep")
  plt.xlabel(col)
  plt.ylabel('count')
  plt.title(f'Countplot for the {col}')

# %%
data['Seasons'].value_counts().plot(kind='pie')
plt.title('Proportion of Bike Rentals by Season')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Proportion of Bike Rentals

# %%
data['Functioning Day'].value_counts().plot(kind='pie')
plt.title('Proportion of Bike Rentals by Functioning Day')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Checking the trends

# %%
sns.lineplot(x='Seasons', y='Rented Bike Count', data=data)
plt.title('Bike Rentals by Seasons')
plt.show()

# %%
sns.lineplot(x='Temperature(?C)', y='Rented Bike Count', data=data)
plt.title('Bike Rentals by Seasons')
plt.show()

# %%
sns.lineplot(x='Hour', y='Rented Bike Count', data=data ,hue='Seasons')
plt.title('Bike Rentals by Hour')
plt.show()

# %% [markdown]
# # Checking Distribution and outliers in data

# %%
plt.figure(figsize=(12,12))
for i,col in enumerate(data.select_dtypes(include='number').columns):
  plt.subplot(5,3,i+1)
  sns.boxplot(x=data[col])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,12))
for i,col in enumerate(data.select_dtypes(include='number').columns) :
  plt.subplot(5,3,i+1)
  sns.histplot(data = data , x = col  , kde = True ,color='blue')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Encoding the Categorical data to numerical

# %%
holiday = pd.get_dummies(data['Holiday'],drop_first=True)
functioning_day = pd.get_dummies(data['Functioning Day'],drop_first=True)
seasons = pd.get_dummies(data['Seasons'],drop_first=True)

# %%
data = pd.concat([data,holiday,functioning_day,seasons],axis=1)
data.head()
# Out:
#    Rented Bike Count  Hour  Temperature(?C)  Humidity(%)  Wind speed (m/s)  \
# 0                254     0             -5.2           37               2.2
# 1                204     1             -5.5           38               0.8
# 2                173     2             -6.0           39               1.0
# 3                107     3             -6.2           40               0.9
# 4                 78     4             -6.0           36               2.3
#
#    Visibility (10m)  Dew point temperature  Solar Radiation (MJ/m2)  \
# 0              2000                  -17.6                      0.0
# 1              2000                  -17.6                      0.0
# 2              2000                  -17.7                      0.0
# 3              2000                  -17.6                      0.0
# 4              2000                  -18.6                      0.0
#
#    Rainfall(mm)  Snowfall (cm)  ...     Holiday Functioning Day  Year Month  \
# 0           0.0            0.0  ...  No Holiday             Yes  2017    12
# 1           0.0            0.0  ...  No Holiday             Yes  2017    12
# 2           0.0            0.0  ...  No Holiday             Yes  2017    12
# 3           0.0            0.0  ...  No Holiday             Yes  2017    12
# 4           0.0            0.0  ...  No Holiday             Yes  2017    12
#
#   Day No Holiday   Yes  Spring  Summer  Winter
# 0   1       True  True   False   False    True
# 1   1       True  True   False   False    True
# 2   1       True  True   False   False    True
# 3   1       True  True   False   False    True
# 4   1       True  True   False   False    True
#
# [5 rows x 21 columns]

# %%
data.drop(['Holiday','Functioning Day','Seasons'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Rented Bike Count  Hour  Temperature(?C)  Humidity(%)  Wind speed (m/s)  \
# 0                254     0             -5.2           37               2.2
# 1                204     1             -5.5           38               0.8
# 2                173     2             -6.0           39               1.0
# 3                107     3             -6.2           40               0.9
# 4                 78     4             -6.0           36               2.3
#
#    Visibility (10m)  Dew point temperature  Solar Radiation (MJ/m2)  \
# 0              2000                  -17.6                      0.0
# 1              2000                  -17.6                      0.0
# 2              2000                  -17.7                      0.0
# 3              2000                  -17.6                      0.0
# 4              2000                  -18.6                      0.0
#
#    Rainfall(mm)  Snowfall (cm)  Year Month Day  No Holiday   Yes  Spring  \
# 0           0.0            0.0  2017    12   1        True  True   False
# 1           0.0            0.0  2017    12   1        True  True   False
# 2           0.0            0.0  2017    12   1        True  True   False
# 3           0.0            0.0  2017    12   1        True  True   False
# 4           0.0            0.0  2017    12   1        True  True   False
#
#    Summer  Winter
# 0   False    True
# 1   False    True
# 2   False    True
# 3   False    True
# 4   False    True

# %% [markdown]
# # Power Transformation
# **The data exhibits significant dispersion and deviates from a normal distribution, indicating high variance and skewness. To address this, we need to stabilize the variance, reduce skewness, and transform the data to align more closely with a normal distribution.**

# %%
cols = data.select_dtypes(include='number').columns
from sklearn.preprocessing import PowerTransformer
transformation = PowerTransformer(method='yeo-johnson')
data[cols]= transformation.fit_transform(data[cols])

# %%
plt.figure(figsize=(12, 12))
for i, col in enumerate(data.select_dtypes(include='number').columns):
    plt.subplot(5, 3, i+1)
    sns.histplot(data=data, x=col,color='blue', kde=True)
plt.tight_layout()

# %%
plt.figure(figsize=(12, 12))
for i, col in enumerate(data.select_dtypes(include='number').columns):
    plt.subplot(5, 3, i+1)
    sns.boxplot(data=data, x=col)
plt.tight_layout()

# %% [markdown]
# # Checking the Correleation

# %%
plt.figure(figsize=(17,17))
sns.heatmap(data.corr() ,annot=True , cmap = "YlGnBu",linewidths=0.5, annot_kws={'size': 12})
plt.title('Correlation Heatmap of the Variables', fontsize=16, fontweight='bold')
plt.show()

# %%
# as we see the temperature and Dew point temperature having strong releation so delete any one

data.drop('Dew point temperature',axis=1,inplace=True)

# %%
data.head()
# Out:
#    Rented Bike Count      Hour  Temperature(?C)  Humidity(%)  \
# 0          -0.530004 -1.902967        -1.524521    -1.038829
# 1          -0.676497 -1.654871        -1.550870    -0.986482
# 2          -0.779424 -1.440263        -1.594819    -0.934363
# 3          -1.047379 -1.244866        -1.612409    -0.882465
# 4          -1.200315 -1.062616        -1.594819    -1.091410
#
#    Wind speed (m/s)  Visibility (10m)  Solar Radiation (MJ/m2)  Rainfall(mm)  \
# 0          0.618103          0.978214                -0.845761     -0.252859
# 1         -0.923651          0.978214                -0.845761     -0.252859
# 2         -0.640327          0.978214                -0.845761     -0.252859
# 3         -0.778203          0.978214                -0.845761     -0.252859
# 4          0.700184          0.978214                -0.845761     -0.252859
#
#    Snowfall (cm)  Year Month Day  No Holiday   Yes  Spring  Summer  Winter
# 0      -0.230785  2017    12   1        True  True   False   False    True
# 1      -0.230785  2017    12   1        True  True   False   False    True
# 2      -0.230785  2017    12   1        True  True   False   False    True
# 3      -0.230785  2017    12   1        True  True   False   False    True
# 4      -0.230785  2017    12   1        True  True   False   False    True

# %% [markdown]
# # Splitting the target and input features

# %%
x = data.iloc[:,1:-1].values
y = data.iloc[:,0].values

# %% [markdown]
# # Splitting the data set in to test and train set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %% [markdown]
# # Apply Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# # Training the different Regression models

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_LR = regressor.predict(x_test)

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
DTR_regressor = DecisionTreeRegressor(random_state = 100)
DTR_regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred_DTR = DTR_regressor.predict(x_test)

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
RFR_regressor = RandomForestRegressor(n_estimators = 100, random_state = 100)
RFR_regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=100)

# %%
y_pred_RFR = RFR_regressor.predict(x_test)

# %% [markdown]
# # Support vector Regression

# %%
from sklearn.svm import SVR

SVR_regressor = SVR(kernel = 'rbf' , C=15.0654)
SVR_regressor.fit(x_train, y_train)
# Out:
# SVR(C=15.0654)

# %%
y_pred_SVR = SVR_regressor.predict(x_test)

# %% [markdown]
# # Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
GBR_regressor = GradientBoostingRegressor(n_estimators=300, learning_rate=0.1, random_state=100)
GBR_regressor.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=300, random_state=100)

# %%
y_pred_GBR = GBR_regressor.predict(x_test)

# %% [markdown]
# # XGB Regressor

# %%
from xgboost import XGBRegressor
XGB_regressor = XGBRegressor(n_estimators=300, learning_rate=0.1, max_depth=9 , reg_alpha=0.81 )
XGB_regressor.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=300, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred_XGB = XGB_regressor.predict(x_test)

# %% [markdown]
# # Evaluation of the Regression Models

# %%
from sklearn.metrics import r2_score

accuracies = {
    'Linear Regression': r2_score(y_test, y_pred_LR),
    'Decision Tree Regressor': r2_score(y_test, y_pred_DTR),
    'Support Vector Regressor': r2_score(y_test, y_pred_SVR),
    'Random Forest Regressor': r2_score(y_test, y_pred_RFR),
    'Gradient Boosting Regressor': r2_score(y_test, y_pred_GBR),
    'XGBoost Regressor': r2_score(y_test, y_pred_XGB)
}
sorted_accuracies = sorted(accuracies.items(), key=lambda x: x[1], reverse=True)
for model, accuracy in sorted_accuracies:
    print(f"{model}: {accuracy:.4f}")
# Out:
# XGBoost Regressor: 0.9247
# Random Forest Regressor: 0.9101
# Gradient Boosting Regressor: 0.9031
# Support Vector Regressor: 0.8838
# Decision Tree Regressor: 0.8391
# Linear Regression: 0.7116
